# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedfarhanuddin/-machinelearning/blob/main/irisdatasetgraphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('/content/Iris_dataset (2).csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.plot(x="SepalLengthCm",y="SepalWidthCm")
plt.xlabel("SepalLength")
plt.ylabel("SepalWidth")
# Out:
# Text(0, 0.5, 'SepalWidth')

# %%
df.plot(kind="bar",x="PetalLengthCm",y="PetalWidthCm")
plt.xlabel("PetalLength")
plt.ylabel("PetalWidth")
# Out:
# Text(0, 0.5, 'PetalWidth')
